# %% [markdown]
# <a href="https://colab.research.google.com/github/Ni7070/Hackerrank-Submission/blob/master/collections_Counter().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **collections.Counter()**
#
#
# A counter is a container that stores elements as dictionary keys, and their counts are stored as dictionary values.
# >>> from collections import Counter
# >>>
# >>> myList = [1,1,2,3,4,5,3,2,3,4,2,1,2,3]
# >>> print Counter(myList)
# Counter({2: 4, 3: 4, 1: 3, 4: 2, 5: 1})
# >>>
# >>> print Counter(myList).items()
# [(1, 3), (2, 4), (3, 4), (4, 2), (5, 1)]
# >>>
# >>> print Counter(myList).keys()
# [1, 2, 3, 4, 5]
# >>>
# >>> print Counter(myList).values()
# [3, 4, 4, 2, 1]
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)<br>
#
# *Sample Input*<br>
#
# 10
# 2 3 4 5 6 8 7 6 5 18
# 6
# 6 55
# 6 45
# 6 55
# 4 40
# 18 60
# 10 50
# *Sample Output*<br>
#
# 200

# %%
from collections import Counter 

noOfShoes = int(input())
availableShoeSizes = (list(map(int, input().split())))
noOfCustomers = int(input())
c = Counter(l)
print(c)                  # element : number of occurance (desc order)
s = 0
for i in range(noOfCustomers):
  size , price = [int(i) for i in input().split()]
  if c[size]>0:           # if that shoe is in the inventory
    s = s + price         # calculate they money
    c[size] -= 1          # number of occurance is reduced by one
print(s)
# Out:
# 10
# 2 3 4 5 6 8 7 6 5 18
# 6
# Counter({5: 2, 6: 2, 2: 1, 3: 1, 4: 1, 8: 1, 7: 1, 18: 1})
# 6 55
# 6 45
# 6 66
# 4 40
# 18 60
# 10 50
# 200
